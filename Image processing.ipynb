# %% [markdown]
# ## IMAGE CLEANING AND DEDEUPLICATION
# This notebook takes the videos I have of each agent and converts them into images. As the videos I took on NVIDIA Shadowplay are 1080p 30fps, I first reduce the framerate to around 3fps otherwise we would get many images which are very similar. I then measure the blur of each image and keep the sharpest ones. I think remove any possible duplicated images. Finally I save all these processed images in a file, ready for use in the ML model section.

# %% [markdown]
# Below I get necessary project paths ready and also any important varibles. I then quickly loop over and count how many videos each agent has

# %%
from pathlib import Path
import os
import pandas as pd
import cv2
import numpy as np

PROJECT_DIR   = Path(r"D:\Valorant ML data")
RAW_VIDEO_DIR = PROJECT_DIR / "Raw videos"   

# Here are some variables that I create now for clarity
TARGET_FPS = 3          # we want to reduce fps from 30 to 3
BLUR_THRESHOLD = 110.0        #the lower this no., the stricter the blur detection
DUPLICATE_MAD_THRESHOLD = 2.0  #a lower no. here mains more likely to label frame as duplicate

# %%
FRAME_OUT_DIR = PROJECT_DIR / "frames_3fps_clean"
FRAME_OUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
#Here I just check the agents list and how many videos each has
agents = []
counts = []
for agent_folder in sorted(RAW_VIDEO_DIR.iterdir()):
    if agent_folder.is_dir():
        n = 0
        for root, _, files in os.walk(agent_folder):
            for f in files:
                if f.lower().endswith(".mp4"):
                    n += 1
        agents.append(agent_folder.name)
        counts.append(n)

counts_df = pd.DataFrame({"agent": agents, "video_count": counts}).sort_values("agent").reset_index(drop=True)
print(counts_df.to_string(index=False))
# Out:
#     agent  video_count
#     Astra            9
#    Breach            8
# Brimstone            8
#   Chamber            8
#    Cipher            8
#     Clove            8
#  Deadlock            8
#      Fade            8
#     Gekko            8
#       Iso            8
#      Jett            8
#      Kayo            8
#      Neon            8
#      Raze            8
#      Sage            8

# %% [markdown]
# Next I define some functions that will help in a bit:
#
# `is_blurry` takes the image and the blur threshold as arguments and computes the variance of Laplacian. If this is low, its more likely the image is blurry. I read a tutorial about this online, but intuitively Im guessing that if variance is too low, then there isnt enough 'change' in  the image and it isnt sharp. This function returns a True of False, and also the value of the variance of the Laplacian
#
# `frames_too_similar` takes 2 greyscaled images and compares them using mean absolute difference (MAD). If the MAD is small then the frames are more similar. The function returns a True or False, and also the value of MAD
#
# `save_frame` takes the image and a savepath and just saves the frame as a jpg without adjusting the res.

# %%
def is_blurry(image_bgr, threshold=BLUR_THRESHOLD):
    grey = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY) #first we convert the image into greyscale
    focus = cv2.Laplacian(grey, cv2.CV_64F).var()
    return (focus < threshold), float(focus)

# %%
def frames_too_similar(prev_grey, curr_grey, mad_threshold=DUPLICATE_MAD_THRESHOLD):
    diff = cv2.absdiff(prev_grey, curr_grey)  #calculate absolute difference
    mad = float(np.mean(diff))                #take the mean of the absolute difference using np.mean()
    return (mad < mad_threshold), mad

# %%
def save_frame(image_bgr, save_path):
    
    save_path = Path(save_path)
    save_path.parent.mkdir(parents=True, exist_ok=True)
    done = cv2.imwrite(str(save_path), image_bgr)
    return done

# %% [markdown]
# Now we define the function that processes one video: samples at 3 fps, removes blurry or near duplicate frames, saves kept frames to `frames_3fps_clean/<Agent>/…`, prints a one-line summary, and returns a pandas table

# %%
def process_single_video(video_path, agent_name=None, out_dir=FRAME_OUT_DIR, target_fps=TARGET_FPS, 
                         blur_thr=BLUR_THRESHOLD, dup_mad_thr=DUPLICATE_MAD_THRESHOLD):    
    #we set up the video path
    video_path = Path(video_path)

    # this sets the agent name
    if agent_name is None:
        agent_name = video_path.parent.name  
    
    cap = cv2.VideoCapture(str(video_path))
    #source fps is found here, the fallback is 30
    src_fps = cap.get(cv2.CAP_PROP_FPS)
    if src_fps is None or src_fps <= 0:
        src_fps = 30.0
    
    #I keep roughly 1 fraem every 'step' frames
    step = max(1, int(round(src_fps / max(1e-6, target_fps))))
    sampled = 0
    kept = 0
    skipped_blur = 0
    skipped_dup = 0
    rows = []
    last_kept_grey = None
    frame_idx = 0
    while True:
        ok, frame_bgr = cap.read()
        if not ok:
            break
        
        #this ensures we only take the frame on our step. I also increase the frame index counter to record this
        if frame_idx % step != 0:
            frame_idx += 1
            continue 
        sampled += 1
        is_blur, focus_val = is_blurry(frame_bgr, threshold=blur_thr) #we call our blur function here

        # duplicate check vs the previous frame
        grey = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2GRAY)
        if last_kept_grey is not None:
            is_dup, mad_val = frames_too_similar(last_kept_grey, grey, mad_threshold=dup_mad_thr)
        else:
            is_dup, mad_val = False, np.nan

        #we only keep images that are not blurry and not duplicates
        keep = (not is_blur) and (not is_dup)
        save_path = out_dir / agent_name / f"{video_path.stem}_{frame_idx:06d}.jpg"

        #now we adjust our counters depending on if the image was kept, was blurry, or was duplicate
        if keep:
            saved_fine = save_frame(frame_bgr, save_path)
            if saved_fine:
                last_kept_grey = grey
                kept += 1
        else:
            if is_blur:
                skipped_blur += 1
            elif is_dup:
                skipped_dup += 1
        # now store a tiny row 
        rows.append({
            "agent": agent_name,
            "video": video_path.name,
            "frame_index": frame_idx,
            "src_fps": float(src_fps),
            "sample_step": int(step),
            "focus": float(focus_val),
            "mad_vs_prev": float(mad_val) if not np.isnan(mad_val) else np.nan,
            "blurry": bool(is_blur),
            "duplicate": bool(is_dup),
            "kept": bool(keep),
            "saved_path": str(save_path) if keep else ""})
        frame_idx += 1
    cap.release()
    print(f"{agent_name}: {video_path.name} | sampled={sampled} kept={kept} "f"blur skipped={skipped_blur} duplicates skipped={skipped_dup}")

    return pd.DataFrame(rows)

# %% [markdown]
# Now we use `process_single_video` to process all the videos inside a single agent folder. Its arguments are the agent foler and the folder where the new frames will be saved

# %%
def process_agent_folder(agent_folder, out_dir=FRAME_OUT_DIR):
    agent_folder = Path(agent_folder)
    agent_name = agent_folder.name
    # find videos
    video_paths = []
    for root, _, files in os.walk(agent_folder):    #here we ignore the _ that results from the walk of the agent_folder folder
        for f in files:
            if f.lower().endswith(".mp4"):         #just to double check, if the file is an mp4 we add it to video_paths list
                video_paths.append(Path(root) / f)
    video_paths = sorted(video_paths)
    
    all_rows = []
    for vp in video_paths:    #now we process each video by calling the appropriate function
        df = process_single_video(video_path=vp, agent_name=agent_name, out_dir=out_dir,
            target_fps=TARGET_FPS, blur_thr=BLUR_THRESHOLD, dup_mad_thr=DUPLICATE_MAD_THRESHOLD)
        if not df.empty:
            all_rows.append(df)
    
    # lastly we combine and print a short summary
    agent_df = pd.concat(all_rows, ignore_index=True)
    total_sampled = len(agent_df)
    total_kept = int(agent_df["kept"].sum())
    keep_rate = total_kept / total_sampled if total_sampled > 0 else 0.0   #to prevent division by 0
    print(f"{agent_name}: videos={len(video_paths)} | sampled={total_sampled} | kept={total_kept} " f"| keep_rate={keep_rate:.2%}")
    return agent_df

# %% [markdown]
# Now we define a function to process all agents:

# %%
def process_all_agents(raw_root=RAW_VIDEO_DIR, out_dir=FRAME_OUT_DIR):
    #we set up the path for our raw videos and where we want our processed videos to go
    raw_root = Path(raw_root)
    out_dir = Path(out_dir)

    agent_logs = []
    for agent_folder in sorted(raw_root.iterdir()):
        if agent_folder.is_dir():
            df = process_agent_folder(agent_folder, out_dir=out_dir)   #here we call our function above
            if not df.empty:
                agent_logs.append(df)

    if agent_logs:
        return pd.concat(agent_logs, ignore_index=True)   #we concat the agent_logs into a pandas dataframe

    # empty fallback with expected columns
    return pd.DataFrame(columns=["agent","video","frame_index","src_fps","sample_step","focus","mad_vs_prev","blurry","duplicate","kept","saved_path"])

# %% [markdown]
# Now the most important function has been defined, we call it and just print some checks to ensure everythig is ok. These checks are important because I realised that some agents had very few images saved. This was the case for the agents I first gathered videos of, hence the first videos were not of the highest quality. Thus, in order to delete less videos I went back and adjusted the necessary parameters (namely the duplicate MAD threshold, I made it higher).

# %%
all_log_df = process_all_agents(raw_root=RAW_VIDEO_DIR, out_dir=FRAME_OUT_DIR)
print("frames saved under:", FRAME_OUT_DIR)

summary_df = (all_log_df.groupby("agent")["kept"].agg(total_sampled="size", kept_frames="sum").reset_index() )
summary_df["keep_rate"] = (summary_df["kept_frames"] / summary_df["total_sampled"]).round(4) 
print("\nPer agent summary:")
print(summary_df.to_string(index=False))
# quick look at the first few log rows 
print("\nLog preview (first 8 rows):")
print(all_log_df.head(8).to_string(index=False))
# Out:
# Astra: Valorant 2025.08.25 - 22.02.06.08.DVR.mp4 | sampled=46 kept=45 blur skipped=0 duplicates skipped=1
# Astra: Valorant 2025.08.25 - 22.04.31.09.DVR.mp4 | sampled=46 kept=1 blur skipped=0 duplicates skipped=45
# Astra: Valorant 2025.08.25 - 22.06.50.11.DVR.mp4 | sampled=46 kept=7 blur skipped=0 duplicates skipped=39
# Astra: Valorant 2025.08.25 - 22.07.44.12.DVR.mp4 | sampled=46 kept=17 blur skipped=0 duplicates skipped=29
# Astra: Valorant 2025.08.25 - 22.08.44.13.DVR.mp4 | sampled=46 kept=1 blur skipped=0 duplicates skipped=45
# Astra: Valorant 2025.08.25 - 22.09.55.14.DVR.mp4 | sampled=46 kept=8 blur skipped=0 duplicates skipped=38
# Astra: Valorant 2025.08.25 - 22.11.24.15.DVR.mp4 | sampled=46 kept=44 blur skipped=2 duplicates skipped=0
# Astra: Valorant 2025.08.25 - 22.12.46.16.DVR.mp4 | sampled=47 kept=47 blur skipped=0 duplicates skipped=0
# Astra: Valorant 2025.08.25 - 22.13.50.17.DVR.mp4 | sampled=47 kept=15 blur skipped=0 duplicates skipped=32
# Astra: videos=9 | sampled=416 | kept=185 | keep_rate=44.47%
# Breach: Valorant 2025.08.25 - 22.24.53.30.DVR.mp4 | sampled=46 kept=45 blur skipped=0 duplicates skipped=1
# Breach: Valorant 2025.08.25 - 22.25.45.32.DVR.mp4 | sampled=46 kept=4 blur skipped=0 duplicates skipped=42
# Breach: Valorant 2025.08.25 - 22.26.13.33.DVR.mp4 | sampled=46 kept=6 blur skipped=0 duplicates skipped=40
# Breach: Valorant 2025.08.25 - 22.27.17.34.DVR.mp4 | sampled=46 kept=41 blur skipped=0 duplicates skipped=5
# Breach: Valorant 2025.08.25 - 22.27.58.35.DVR.mp4 | sampled=46 kept=4 blur skipped=0 duplicates skipped=42
# Breach: Valorant 2025.08.25 - 22.28.49.36.DVR.mp4 | sampled=48 kept=47 blur skipped=0 duplicates skipped=1
# Breach: Valorant 2025.08.25 - 22.29.19.37.DVR.mp4 | sampled=47 kept=47 blur skipped=0 duplicates skipped=0
# Breach: Valorant 2025.08.25 - 22.29.48.38.DVR.mp4 | sampled=48 kept=47 blur skipped=0 duplicates skipped=1
# Breach: videos=8 | sampled=373 | kept=241 | keep_rate=64.61%
# Brimstone: Valorant 2025.08.25 - 22.30.59.40.DVR.mp4 | sampled=47 kept=44 blur skipped=3 duplicates skipped=0
# Brimstone: Valorant 2025.08.25 - 22.31.28.41.DVR.mp4 | sampled=46 kept=35 blur skipped=0 duplicates skipped=11
# Brimstone: Valorant 2025.08.25 - 22.32.04.42.DVR.mp4 | sampled=47 kept=28 blur skipped=0 duplicates skipped=19
# Brimstone: Valorant 2025.08.25 - 22.32.27.43.DVR.mp4 | sampled=46 kept=46 blur skipped=0 duplicates skipped=0
# Brimstone: Valorant 2025.08.25 - 22.32.56.44.DVR.mp4 | sampled=48 kept=15 blur skipped=0 duplicates skipped=33
# Brimstone: Valorant 2025.08.25 - 22.33.32.45.DVR.mp4 | sampled=46 kept=45 blur skipped=0 duplicates skipped=1
# Brimstone: Valorant 2025.08.25 - 22.34.21.46.DVR.mp4 | sampled=48 kept=46 blur skipped=0 duplicates skipped=2
# Brimstone: Valorant 2025.08.25 - 22.35.02.47.DVR.mp4 | sampled=46 kept=46 blur skipped=0 duplicates skipped=0
# Brimstone: videos=8 | sampled=374 | kept=305 | keep_rate=81.55%
# Chamber: Valorant 2025.08.25 - 22.36.25.49.DVR.mp4 | sampled=47 kept=45 blur skipped=0 duplicates skipped=2
# Chamber: Valorant 2025.08.25 - 22.36.49.50.DVR.mp4 | sampled=46 kept=33 blur skipped=0 duplicates skipped=13
# Chamber: Valorant 2025.08.25 - 22.37.25.51.DVR.mp4 | sampled=48 kept=45 blur skipped=0 duplicates skipped=3
# Chamber: Valorant 2025.08.25 - 22.38.04.53.DVR.mp4 | sampled=45 kept=39 blur skipped=0 duplicates skipped=6
# Chamber: Valorant 2025.08.25 - 22.38.36.54.DVR.mp4 | sampled=46 kept=44 blur skipped=0 duplicates skipped=2
# Chamber: Valorant 2025.08.25 - 22.39.08.55.DVR.mp4 | sampled=48 kept=48 blur skipped=0 duplicates skipped=0
# Chamber: Valorant 2025.08.25 - 22.39.41.56.DVR.mp4 | sampled=48 kept=48 blur skipped=0 duplicates skipped=0
# Chamber: Valorant 2025.08.25 - 22.40.21.57.DVR.mp4 | sampled=46 kept=45 blur skipped=1 duplicates skipped=0
# Chamber: videos=8 | sampled=374 | kept=347 | keep_rate=92.78%
# Cipher: Valorant 2025.08.25 - 22.58.33.86.DVR.mp4 | sampled=46 kept=46 blur skipped=0 duplicates skipped=0
# Cipher: Valorant 2025.08.25 - 22.59.00.87.DVR.mp4 | sampled=48 kept=34 blur skipped=0 duplicates skipped=14
# Cipher: Valorant 2025.08.25 - 22.59.21.88.DVR.mp4 | sampled=48 kept=34 blur skipped=0 duplicates skipped=14
# Cipher: Valorant 2025.08.25 - 22.59.43.89.DVR.mp4 | sampled=46 kept=41 blur skipped=0 duplicates skipped=5
# Cipher: Valorant 2025.08.25 - 23.00.28.90.DVR.mp4 | sampled=48 kept=46 blur skipped=0 duplicates skipped=2
# Cipher: Valorant 2025.08.25 - 23.00.55.91.DVR.mp4 | sampled=46 kept=45 blur skipped=0 duplicates skipped=1
# Cipher: Valorant 2025.08.25 - 23.01.47.92.DVR.mp4 | sampled=46 kept=45 blur skipped=0 duplicates skipped=1
# Cipher: Valorant 2025.08.25 - 23.02.13.93.DVR.mp4 | sampled=47 kept=46 blur skipped=0 duplicates skipped=1
# Cipher: videos=8 | sampled=375 | kept=337 | keep_rate=89.87%
# Clove: Valorant 2025.08.25 - 22.46.05.68.DVR.mp4 | sampled=48 kept=48 blur skipped=0 duplicates skipped=0
# Clove: Valorant 2025.08.25 - 22.46.34.69.DVR.mp4 | sampled=48 kept=46 blur skipped=0 duplicates skipped=2
# Clove: Valorant 2025.08.25 - 22.47.03.70.DVR.mp4 | sampled=48 kept=43 blur skipped=0 duplicates skipped=5
# Clove: Valorant 2025.08.25 - 22.47.29.71.DVR.mp4 | sampled=46 kept=40 blur skipped=0 duplicates skipped=6
# Clove: Valorant 2025.08.25 - 22.47.53.72.DVR.mp4 | sampled=45 kept=8 blur skipped=0 duplicates skipped=37
# Clove: Valorant 2025.08.25 - 22.48.19.73.DVR.mp4 | sampled=46 kept=46 blur skipped=0 duplicates skipped=0
# Clove: Valorant 2025.08.25 - 22.52.12.74.DVR.mp4 | sampled=47 kept=47 blur skipped=0 duplicates skipped=0
# Clove: Valorant 2025.08.25 - 22.52.59.75.DVR.mp4 | sampled=48 kept=46 blur skipped=0 duplicates skipped=2
# Clove: videos=8 | sampled=376 | kept=324 | keep_rate=86.17%
# Deadlock: Valorant 2025.08.25 - 22.54.02.77.DVR.mp4 | sampled=46 kept=46 blur skipped=0 duplicates skipped=0
# Deadlock: Valorant 2025.08.25 - 22.54.26.78.DVR.mp4 | sampled=46 kept=36 blur skipped=0 duplicates skipped=10
# Deadlock: Valorant 2025.08.25 - 22.54.47.79.DVR.mp4 | sampled=46 kept=18 blur skipped=0 duplicates skipped=28
# Deadlock: Valorant 2025.08.25 - 22.55.09.80.DVR.mp4 | sampled=48 kept=40 blur skipped=0 duplicates skipped=8
# Deadlock: Valorant 2025.08.25 - 22.55.32.81.DVR.mp4 | sampled=48 kept=44 blur skipped=0 duplicates skipped=4
# Deadlock: Valorant 2025.08.25 - 22.55.56.82.DVR.mp4 | sampled=46 kept=46 blur skipped=0 duplicates skipped=0
# Deadlock: Valorant 2025.08.25 - 22.56.24.83.DVR.mp4 | sampled=48 kept=41 blur skipped=0 duplicates skipped=7
# Deadlock: Valorant 2025.08.25 - 22.57.16.84.DVR.mp4 | sampled=46 kept=28 blur skipped=0 duplicates skipped=18
# Deadlock: videos=8 | sampled=374 | kept=299 | keep_rate=79.95%
# Fade: Valorant 2025.08.25 - 23.08.53.105.DVR.mp4 | sampled=47 kept=45 blur skipped=2 duplicates skipped=0
# Fade: Valorant 2025.08.25 - 23.09.42.106.DVR.mp4 | sampled=47 kept=28 blur skipped=0 duplicates skipped=19
# Fade: Valorant 2025.08.25 - 23.10.06.107.DVR.mp4 | sampled=45 kept=30 blur skipped=0 duplicates skipped=15
# Fade: Valorant 2025.08.25 - 23.10.40.108.DVR.mp4 | sampled=45 kept=45 blur skipped=0 duplicates skipped=0
# Fade: Valorant 2025.08.25 - 23.11.09.109.DVR.mp4 | sampled=47 kept=37 blur skipped=0 duplicates skipped=10
# Fade: Valorant 2025.08.25 - 23.11.36.110.DVR.mp4 | sampled=46 kept=45 blur skipped=1 duplicates skipped=0
# Fade: Valorant 2025.08.25 - 23.12.06.111.DVR.mp4 | sampled=45 kept=44 blur skipped=1 duplicates skipped=0
# Fade: Valorant 2025.08.25 - 23.12.34.112.DVR.mp4 | sampled=47 kept=47 blur skipped=0 duplicates skipped=0
# Fade: videos=8 | sampled=369 | kept=321 | keep_rate=86.99%
# Gekko: Valorant 2025.08.25 - 22.41.06.59.DVR.mp4 | sampled=47 kept=46 blur skipped=0 duplicates skipped=1
# Gekko: Valorant 2025.08.25 - 22.41.29.60.DVR.mp4 | sampled=48 kept=44 blur skipped=0 duplicates skipped=4
# Gekko: Valorant 2025.08.25 - 22.41.51.61.DVR.mp4 | sampled=47 kept=26 blur skipped=0 duplicates skipped=21
# Gekko: Valorant 2025.08.25 - 22.42.12.62.DVR.mp4 | sampled=48 kept=45 blur skipped=0 duplicates skipped=3
# Gekko: Valorant 2025.08.25 - 22.42.36.63.DVR.mp4 | sampled=47 kept=46 blur skipped=0 duplicates skipped=1
# Gekko: Valorant 2025.08.25 - 22.43.00.64.DVR.mp4 | sampled=47 kept=46 blur skipped=0 duplicates skipped=1
# Gekko: Valorant 2025.08.25 - 22.43.35.65.DVR.mp4 | sampled=47 kept=47 blur skipped=0 duplicates skipped=0
# Gekko: Valorant 2025.08.25 - 22.44.02.66.DVR.mp4 | sampled=45 kept=45 blur skipped=0 duplicates skipped=0
# Gekko: videos=8 | sampled=376 | kept=345 | keep_rate=91.76%
# Iso: Valorant 2025.08.25 - 23.19.04.123.DVR.mp4 | sampled=48 kept=46 blur skipped=0 duplicates skipped=2
# Iso: Valorant 2025.08.25 - 23.19.34.124.DVR.mp4 | sampled=48 kept=40 blur skipped=0 duplicates skipped=8
# Iso: Valorant 2025.08.25 - 23.19.56.125.DVR.mp4 | sampled=46 kept=46 blur skipped=0 duplicates skipped=0
# Iso: Valorant 2025.08.25 - 23.20.18.126.DVR.mp4 | sampled=48 kept=43 blur skipped=0 duplicates skipped=5
# Iso: Valorant 2025.08.25 - 23.20.41.127.DVR.mp4 | sampled=46 kept=42 blur skipped=0 duplicates skipped=4
# Iso: Valorant 2025.08.25 - 23.21.10.128.DVR.mp4 | sampled=48 kept=44 blur skipped=0 duplicates skipped=4
# Iso: Valorant 2025.08.25 - 23.21.44.129.DVR.mp4 | sampled=48 kept=48 blur skipped=0 duplicates skipped=0
# Iso: Valorant 2025.08.25 - 23.22.17.130.DVR.mp4 | sampled=47 kept=47 blur skipped=0 duplicates skipped=0
# Iso: videos=8 | sampled=379 | kept=356 | keep_rate=93.93%
# Jett: Valorant 2025.08.25 - 22.15.41.19.DVR.mp4 | sampled=46 kept=45 blur skipped=0 duplicates skipped=1
# Jett: Valorant 2025.08.25 - 22.17.48.21.DVR.mp4 | sampled=46 kept=1 blur skipped=0 duplicates skipped=45
# Jett: Valorant 2025.08.25 - 22.18.17.22.DVR.mp4 | sampled=48 kept=1 blur skipped=0 duplicates skipped=47
# Jett: Valorant 2025.08.25 - 22.18.44.23.DVR.mp4 | sampled=45 kept=2 blur skipped=0 duplicates skipped=43
# Jett: Valorant 2025.08.25 - 22.20.01.25.DVR.mp4 | sampled=47 kept=41 blur skipped=0 duplicates skipped=6
# Jett: Valorant 2025.08.25 - 22.21.02.26.DVR.mp4 | sampled=46 kept=34 blur skipped=0 duplicates skipped=12
# Jett: Valorant 2025.08.25 - 22.21.44.27.DVR.mp4 | sampled=48 kept=45 blur skipped=0 duplicates skipped=3
# Jett: Valorant 2025.08.25 - 22.22.30.28.DVR.mp4 | sampled=47 kept=46 blur skipped=0 duplicates skipped=1
# Jett: videos=8 | sampled=373 | kept=215 | keep_rate=57.64%
# Kayo: Valorant 2025.08.25 - 23.30.04.141.DVR.mp4 | sampled=47 kept=47 blur skipped=0 duplicates skipped=0
# Kayo: Valorant 2025.08.25 - 23.30.28.142.DVR.mp4 | sampled=48 kept=48 blur skipped=0 duplicates skipped=0
# Kayo: Valorant 2025.08.25 - 23.30.53.143.DVR.mp4 | sampled=46 kept=37 blur skipped=0 duplicates skipped=9
# Kayo: Valorant 2025.08.25 - 23.31.16.144.DVR.mp4 | sampled=46 kept=42 blur skipped=0 duplicates skipped=4
# Kayo: Valorant 2025.08.25 - 23.31.39.145.DVR.mp4 | sampled=45 kept=44 blur skipped=0 duplicates skipped=1
# Kayo: Valorant 2025.08.25 - 23.32.05.146.DVR.mp4 | sampled=48 kept=48 blur skipped=0 duplicates skipped=0
# Kayo: Valorant 2025.08.25 - 23.32.30.147.DVR.mp4 | sampled=48 kept=46 blur skipped=0 duplicates skipped=2
# Kayo: Valorant 2025.08.25 - 23.33.00.148.DVR.mp4 | sampled=47 kept=47 blur skipped=0 duplicates skipped=0
# Kayo: videos=8 | sampled=375 | kept=359 | keep_rate=95.73%
# Neon: Valorant 2025.08.25 - 23.03.29.95.DVR.mp4 | sampled=47 kept=47 blur skipped=0 duplicates skipped=0
# Neon: Valorant 2025.08.25 - 23.03.52.96.DVR.mp4 | sampled=47 kept=29 blur skipped=0 duplicates skipped=18
# Neon: Valorant 2025.08.25 - 23.04.13.97.DVR.mp4 | sampled=46 kept=45 blur skipped=0 duplicates skipped=1
# Neon: Valorant 2025.08.25 - 23.04.35.98.DVR.mp4 | sampled=46 kept=43 blur skipped=0 duplicates skipped=3
# Neon: Valorant 2025.08.25 - 23.04.56.99.DVR.mp4 | sampled=48 kept=31 blur skipped=0 duplicates skipped=17
# Neon: Valorant 2025.08.25 - 23.05.19.100.DVR.mp4 | sampled=47 kept=46 blur skipped=0 duplicates skipped=1
# Neon: Valorant 2025.08.25 - 23.06.13.101.DVR.mp4 | sampled=46 kept=46 blur skipped=0 duplicates skipped=0
# Neon: Valorant 2025.08.25 - 23.07.05.102.DVR.mp4 | sampled=48 kept=48 blur skipped=0 duplicates skipped=0
# Neon: videos=8 | sampled=375 | kept=335 | keep_rate=89.33%
# Raze: Valorant 2025.08.25 - 23.13.20.114.DVR.mp4 | sampled=46 kept=45 blur skipped=1 duplicates skipped=0
# Raze: Valorant 2025.08.25 - 23.13.41.115.DVR.mp4 | sampled=46 kept=27 blur skipped=0 duplicates skipped=19
# Raze: Valorant 2025.08.25 - 23.14.23.116.DVR.mp4 | sampled=48 kept=48 blur skipped=0 duplicates skipped=0
# Raze: Valorant 2025.08.25 - 23.14.50.117.DVR.mp4 | sampled=47 kept=44 blur skipped=0 duplicates skipped=3
# Raze: Valorant 2025.08.25 - 23.15.20.118.DVR.mp4 | sampled=48 kept=43 blur skipped=0 duplicates skipped=5
# Raze: Valorant 2025.08.25 - 23.15.44.119.DVR.mp4 | sampled=45 kept=40 blur skipped=0 duplicates skipped=5
# Raze: Valorant 2025.08.25 - 23.16.12.120.DVR.mp4 | sampled=47 kept=47 blur skipped=0 duplicates skipped=0
# Raze: Valorant 2025.08.25 - 23.16.39.121.DVR.mp4 | sampled=48 kept=47 blur skipped=0 duplicates skipped=1
# Raze: videos=8 | sampled=375 | kept=341 | keep_rate=90.93%
# Sage: Valorant 2025.08.25 - 23.26.01.132.DVR.mp4 | sampled=47 kept=46 blur skipped=1 duplicates skipped=0
# Sage: Valorant 2025.08.25 - 23.26.25.133.DVR.mp4 | sampled=48 kept=44 blur skipped=0 duplicates skipped=4
# Sage: Valorant 2025.08.25 - 23.26.45.134.DVR.mp4 | sampled=48 kept=42 blur skipped=0 duplicates skipped=6
# Sage: Valorant 2025.08.25 - 23.27.09.135.DVR.mp4 | sampled=47 kept=46 blur skipped=1 duplicates skipped=0
# Sage: Valorant 2025.08.25 - 23.27.31.136.DVR.mp4 | sampled=47 kept=45 blur skipped=0 duplicates skipped=2
# Sage: Valorant 2025.08.25 - 23.27.59.137.DVR.mp4 | sampled=46 kept=46 blur skipped=0 duplicates skipped=0
# Sage: Valorant 2025.08.25 - 23.28.26.138.DVR.mp4 | sampled=46 kept=46 blur skipped=0 duplicates skipped=0
# Sage: Valorant 2025.08.25 - 23.28.51.139.DVR.mp4 | sampled=46 kept=46 blur skipped=0 duplicates skipped=0
# Sage: videos=8 | sampled=375 | kept=361 | keep_rate=96.27%
# frames saved under: D:\Valorant ML data\frames_3fps_clean
#
# Per agent summary:
#     agent  total_sampled  kept_frames  keep_rate
#     Astra            416          185     0.4447
#    Breach            373          241     0.6461
# Brimstone            374          305     0.8155
#   Chamber            374          347     0.9278
#    Cipher            375          337     0.8987
#     Clove            376          324     0.8617
#  Deadlock            374          299     0.7995
#      Fade            369          321     0.8699
#     Gekko            376          345     0.9176
#       Iso            379          356     0.9393
#      Jett            373          215     0.5764
#      Kayo            375          359     0.9573
#      Neon            375          335     0.8933
#      Raze            375          341     0.9093
#      Sage            375          361     0.9627
#
# Log preview (first 8 rows):
# agent                                     video  frame_index   src_fps  sample_step      focus  mad_vs_prev  blurry  duplicate  kept                                                                                   saved_path
# Astra Valorant 2025.08.25 - 22.02.06.08.DVR.mp4            0 59.997152           20 601.297629          NaN   False      False  True D:\Valorant ML data\frames_3fps_clean\Astra\Valorant 2025.08.25 - 22.02.06.08.DVR_000000.jpg
# Astra Valorant 2025.08.25 - 22.02.06.08.DVR.mp4           20 59.997152           20 583.403057    29.131846   False      False  True D:\Valorant ML data\frames_3fps_clean\Astra\Valorant 2025.08.25 - 22.02.06.08.DVR_000020.jpg
# Astra Valorant 2025.08.25 - 22.02.06.08.DVR.mp4           40 59.997152           20 592.966748    28.703559   False      False  True D:\Valorant ML data\frames_3fps_clean\Astra\Valorant 2025.08.25 - 22.02.06.08.DVR_000040.jpg
# Astra Valorant 2025.08.25 - 22.02.06.08.DVR.mp4           60 59.997152           20 595.488528    25.473220   False      False  True D:\Valorant ML data\frames_3fps_clean\Astra\Valorant 2025.08.25 - 22.02.06.08.DVR_000060.jpg
# Astra Valorant 2025.08.25 - 22.02.06.08.DVR.mp4           80 59.997152           20 621.384709    26.755189   False      False  True D:\Valorant ML data\frames_3fps_clean\Astra\Valorant 2025.08.25 - 22.02.06.08.DVR_000080.jpg
# Astra Valorant 2025.08.25 - 22.02.06.08.DVR.mp4          100 59.997152           20 636.641363    29.114295   False      False  True D:\Valorant ML data\frames_3fps_clean\Astra\Valorant 2025.08.25 - 22.02.06.08.DVR_000100.jpg
# Astra Valorant 2025.08.25 - 22.02.06.08.DVR.mp4          120 59.997152           20 622.742855    25.616761   False      False  True D:\Valorant ML data\frames_3fps_clean\Astra\Valorant 2025.08.25 - 22.02.06.08.DVR_000120.jpg
# Astra Valorant 2025.08.25 - 22.02.06.08.DVR.mp4          140 59.997152           20 621.962070    31.539496   False      False  True D:\Valorant ML data\frames_3fps_clean\Astra\Valorant 2025.08.25 - 22.02.06.08.DVR_000140.jpg
